# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('text_emotion.csv')

# %%
df
# Out:
#          tweet_id   sentiment         author  \
# 0      1956967341       empty     xoshayzers
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043   happiness       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# ...

# %%
df.drop(['tweet_id', 'author'], axis =1, inplace = True)

# %%
df = df.loc[(df['sentiment']=='enthusiasm')| (df['sentiment']=='sadness')]

# %%
df.loc[df['sentiment']=='enthusiasm', 'sentiment'] =1
df.loc[df['sentiment']=='sadness', 'sentiment'] = 0

# %%
x = df['content']
y = df['sentiment']

# %%
#x = np.asarray(x).astype(np.float32)
y = np.asarray(y).astype(np.float32)

# %%
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
#creating a split (train/test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=45)

# %%
from tensorflow.keras.models import Sequential 
sentiment = Sequential()

# %%
from tensorflow.keras.layers import Embedding
max_size = 20000
max_length = 130
sentiment.add(Embedding(input_dim = max_size, 
                    output_dim = 10,
                    input_shape = (max_length - 1,)))

# %%
from tensorflow.keras.layers import LSTM 
sentiment.add(LSTM(units = 128))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[74], line 2
#       1 from tensorflow.keras.layers import LSTM
# ----> 2 sentiment.add(LSTM(units = 128))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\training\tracking\base.py:457, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     455 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456 try:
# --> 457   result = method(self, *args, **kwargs)
#     458 finally:
#     459   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\sequential.py:221, in Sequential.add(self, layer)
#     216     self._has_explicit_input_shape = True
#     218 elif self.outputs:
# ...

# %%
sentiment.add(LSTM(units = 64))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 sentiment.add(LSTM(units = 64))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\training\tracking\base.py:457, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     455 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456 try:
# --> 457   result = method(self, *args, **kwargs)
#     458 finally:
#     459   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\sequential.py:221, in Sequential.add(self, layer)
#     216     self._has_explicit_input_shape = True
#     218 elif self.outputs:
#     219   # If the model is being built continuously on top of an input layer:
#     220   # refresh its output.
# ...

# %%
from tensorflow.keras.layers import Dense
sentiment.add(Dense(units=100, activation='relu'))

#signlangmodel.add(Dense(units=10, activation='softmax'))

# %%
from tensorflow.keras.layers import Dropout, Dense 
sentiment.add(Dropout(rate=0.5))

# %%
sentiment.add(Dense(units=5, activation ='softmax'))

# %%
sentiment.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 129, 10)           200000
# _________________________________________________________________
# dense_4 (Dense)              (None, 129, 100)          1100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 129, 100)          0
# _________________________________________________________________
# dense_5 (Dense)              (None, 129, 5)            505
# ...
# Total params: 201,605
# Trainable params: 201,605
# Non-trainable params: 0
# _________________________________________________________________

# %%
sentiment.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
sentiment.fit(x, y, epochs=5)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 129) for input Tensor("embedding_2_input:0", shape=(None, 129), dtype=float32), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 2
#       1 sentiment.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 2 sentiment.fit(x, y, epochs=5)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py:108, in enable_multi_worker.<locals>._method_wrapper(self, *args, **kwargs)
#     106 def _method_wrapper(self, *args, **kwargs):
#     107   if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108     return method(self, *args, **kwargs)
#     110   # Running inside `run_distribute_coordinator` already.
# ...

# %%
scores = sentiment.evaluate(x, y, verbose=0)
print("%s: %.2f%%" % (sentiment.metrics_names[1], scores[1]*100))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 129) for input Tensor("embedding_2_input:0", shape=(None, 129), dtype=float32), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 scores = sentiment.evaluate(x, y, verbose=0)
#       2 print("%s: %.2f%%" % (sentiment.metrics_names[1], scores[1]*100))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py:108, in enable_multi_worker.<locals>._method_wrapper(self, *args, **kwargs)
#     106 def _method_wrapper(self, *args, **kwargs):
#     107   if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108     return method(self, *args, **kwargs)
#     110   # Running inside `run_distribute_coordinator` already.
#     111   if dc_context.get_current_worker_context():
# ...
